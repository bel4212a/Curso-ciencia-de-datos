# %% [markdown]
# # Graficando con pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib notebook

# %% [markdown]
# Estilos predefinidos de matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-colorblind")

# %%
# Creando un dataframe
array = np.random.random(60).reshape(15, 4)
df = pd.DataFrame(array, columns = ["A", "B", "C", "D"])

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.052007  0.949890  0.135586  0.644314
# 1  0.007197  0.029237  0.794036  0.482203
# 2  0.060660  0.074016  0.074949  0.784479
# 3  0.869912  0.777187  0.615541  0.205265
# 4  0.551053  0.015318  0.396930  0.442312

# %% [markdown]
# Grafica de lineas

# %%
df.plot(kind = 'line')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Grafica de puntos

# %%
df.plot('A', 'B', kind = "scatter");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Tambien es posible definir el tipo de grafico con el formato df.plot.type, usando los siguientes tipos:
#
#     'line' : line plot (default)
#     'bar' : vertical bar plot
#     'barh' : horizontal bar plot
#     'hist' : histogram
#     'box' : boxplot
#     'kde' : Kernel Density Estimation plot
#     'density' : same as 'kde'
#     'area' : area plot
#     'pie' : pie plot
#     'scatter' : scatter plot
#     'hexbin' : hexbin plot

# %%
df.plot.scatter("A", "B", s= 100, c='r')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter("A", "B", c = "D", s = df["D"]*100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter("A", "B", c = "D", s = df["D"]*100, colormap = 'viridis')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = df.plot.scatter('A', 'C', c='B', s=df['B']*100, colormap='viridis')
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
df.plot.box();

# %%
df.plot.hist(alpha=0.5);

# %%
df.plot.kde();

# %% [markdown]
# Mas de kde en https://en.wikipedia.org/wiki/Kernel_density_estimation

# %% [markdown]
# ### pandas.plotting

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
# %matplotlib notebook
pd.plotting.scatter_matrix(iris);
# Out:
# <img src="data:image/png;base64,..." width="738.4">

# %%
plt.figure()
pd.plotting.parallel_coordinates(iris, 'Name');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %%
v1 = pd.Series(np.random.normal(0,10,1000), name='v1')
v2 = pd.Series(2*v1 + np.random.normal(60,15,1000), name='v2')

# %%
fig, ax = plt.subplots()
ax.hist(v1, alpha=0.7, bins=np.arange(-50,150,5), label='v1');
ax.hist(v2, alpha=0.7, bins=np.arange(-50,150,5), label='v2');
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.hist([v1, v2], histtype='barstacked', density=True);
v3 = np.concatenate((v1,v2))
sns.kdeplot(v3);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.distplot(v3, hist_kws={'color': 'Teal'}, kde_kws={'color': 'Navy'});
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.jointplot(v1, v2, alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
grid = sns.jointplot(v1, v2, alpha=0.4);
grid.ax_joint.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.jointplot(v1, v2, kind='hex');
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
sns.set_style('white')

sns.jointplot(v1, v2, kind='kde', space=0);
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
sns.pairplot(iris, hue='Name', diag_kind='kde', height=1.5);
# Out:
# <img src="data:image/png;base64,..." width="732">

# %%
plt.figure(figsize=(8,6))
plt.subplot(121)
sns.swarmplot('Name', 'SepalLength', data=iris);
plt.subplot(122)
sns.violinplot('Name', 'SepalLength', data=iris);
# Out:
# <img src="data:image/png;base64,..." width="800">
