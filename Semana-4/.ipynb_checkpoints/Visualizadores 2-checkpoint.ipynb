# %% [markdown]
# # Subplots

# %% [markdown]
# Nos permite graficas varias figuras en el mismo lienzo por medio de la creacion de varios ejes diferentes.

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
plt.subplots?

# %%
import numpy as np
x = np.linspace(1, 10, 100)
y1 = x
y2 = x**2

fig, ax = plt.subplots(1, 2, sharey = True)
ax[0].plot(x, y1)
ax[1].plot(x, y2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y3 = x**2.1
ax[1].plot(x, 10*y3)

# %%
x = np.linspace(1, 10, 100)
y1 = x
y2 = x**2
y3 = np.cos(x)
y4 = np.sin(x)

fig, ax = plt.subplots(2, 2)
ax[0, 0].plot(x, y1)
ax[0, 1].plot(x, y2)
ax[1, 0].plot(x, y3)
ax[1, 1].plot(x, y4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Histogramas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
datos = np.random.randint(1, 7, 1000)
fig, ax = plt.subplots()
ax.hist(datos, bins = 6, align = 'mid', edgecolor = "r")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

#10**(n+1)= 10, 100, 1000, and 10000 
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size = sample_size)
    axs[n].hist(sample)
    axs[n].set_title(f'n={sample_size}')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
perros = 2
gatos = 7
print("mi casa mide {} metros y tengo {} perros".format(5, perros))
print(f'Yo tengo dos {perros} perros y {gatos} gatos')
# Out:
# mi casa mide 5 metros y tengo 2 perros
# Yo tengo dos 2 perros y 7 gatos

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, sharex=True)
axs = [ax1,ax2,ax3,ax4]

#10**(n+1)= 10, 100, 1000, and 10000 
for n in range(0,len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=0.0, scale=1.0, size = sample_size)
    axs[n].hist(sample, bins = 100)
    axs[n].set_title(f'n={sample_size}')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3, 3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
lower_right.scatter(X, Y)
top_histogram.hist(X, bins=100)
side_histogram.hist(Y, bins=100, orientation='horizontal')
plt.show()

# %%
top_histogram.clear()
top_histogram.hist(X, bins=100)
side_histogram.clear()
side_histogram.hist(Y, bins=100, orientation='horizontal')
# flip the side histogram's x axis
side_histogram.invert_xaxis()

# %% [markdown]
# ## <span class="burk">MINIDESAFIO</span>

# %% [markdown]
# **1.** Cree seis graficos en un solo lienzo que grafique las funciones trigonometricas. Procure que el eje x sea igual para todas.
#
# **2.** Realice una simulacion del juego de un dado de 12 caras (si existe), y realice un millon de lanzamientos. Despues de esta simulacion, cual es el valor mas probable?
#
# **3.** Realice una simulacion del juego de baloto. Investigue un poco sobre como funciona. Realice diez millones de juegos. Despues de esto, elija la combinacion ganadora de numeros.
#
# **4.** Realice una grafic similar a la utlima realizada, pero comparando las distribuciones gamma y normal. Use color rojo.

# %%
# Punto 1
x = np.linspace(0, np.pi/2-0.01, 100)
x2 = np.linspace(np.pi/2+0.01, 3*np.pi/2-0.01, 100)
x3 = np.linspace(3*np.pi/2-0.01, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = 1 / np.tan(x)
y5 = 1 / np.cos(x)
y6 = 1 / np.sin(x)
fig, ax = plt.subplots(2, 3)
ax[0, 0].plot(x, y1)
ax[0, 1].plot(x, y2)
ax[0, 2].plot(x, y3)
ax[1, 0].plot(x, y4)
ax[1, 1].plot(x, y5)
ax[1, 2].plot(x, y6)
# Out:
# <ipython-input-38-a831eff26497>:8: RuntimeWarning: divide by zero encountered in true_divide
#   y4 = 1 / np.tan(x)
# <ipython-input-38-a831eff26497>:10: RuntimeWarning: divide by zero encountered in true_divide
#   y6 = 1 / np.sin(x)
# <img src="data:image/png;base64,..." width="640">

# %%
#punto 2
juegos = np.random.randint(1, 13, 1000000)
fig, ax = plt.subplots()
ax.hist(juegos, bins = 12, edgecolor = "r")
ax.set_xticklabels(np.arange(1, 12))
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8')]

# %%
# Punto 3
balotos1 = np.random.randint(1, 44, 10000000)
balotos2 = np.random.randint(1, 17, 10000000)
fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].hist(balotos1, bins = 43, edgecolor = 'r')
ax[1].hist(balotos2, bins = 16, edgecolor = 'r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Diagramas de caja y bigotes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal': normal_sample, 
                   'random': random_sample, 
                   'gamma': gamma_sample})
df.head()
# Out:
#      normal    random     gamma
# 0  0.841079  0.029528  4.068604
# 1  0.428171  0.624584  0.400651
# 2  0.587794  0.910257  1.845473
# 3 -1.010113  0.174311  3.505861
# 4 -0.735795  0.979001  1.606679

# %%
df.describe()
# Out:
#              normal        random         gamma
# count  10000.000000  10000.000000  10000.000000
# mean      -0.004976      0.500362      1.995952
# std        1.005282      0.288315      1.416305
# min       -3.517875      0.000004      0.014858
# 25%       -0.679042      0.251362      0.955418
# 50%       -0.006801      0.498988      1.668991
# 75%        0.674030      0.747860      2.686035
# max        3.626228      0.999961     10.387491

# %%
fig, ax = plt.subplots()
# create a boxplot of the normal data, assign the output to a variable to supress output
ax.boxplot(df['normal'], whis = 'range')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-58-ff3141cf37f3>:3: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   ax.boxplot(df['normal'], whis = 'range')
# {'whiskers': [<matplotlib.lines.Line2D at 0x1918afdc0a0>,
#   <matplotlib.lines.Line2D at 0x1918afdc400>],
#  'caps': [<matplotlib.lines.Line2D at 0x1918afdc760>,
#   <matplotlib.lines.Line2D at 0x1918afdcac0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1918afb7580>],
#  'medians': [<matplotlib.lines.Line2D at 0x1918afdce20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1918afe6160>],
#  'means': []}

# %%
plt.clf()
plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')
plt.show()
# Out:
# <ipython-input-59-cf82422e69bc>:2: MatplotlibDeprecationWarning: Setting whis to 'range' is deprecated since 3.2 and support for it will be removed two minor releases later; set it to [0, 100] to achieve the same effect.
#   plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

# %%
fig, ax = plt.subplots()
plt.boxplot([df['normal'], df['random'], df['gamma']])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Mapas de calor

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fig, ax = plt.subplots()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)
plt.hist2d(X, Y, bins=25)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.hist2d(X, Y, bins=50)
plt.show()

# %%
plt.colorbar()

# %%
fig, ax = plt.subplots()
ax.scatter(X, Y, marker = ".", s= 0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
